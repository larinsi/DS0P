# %% [markdown]
# <a href="https://colab.research.google.com/github/larinsi/DS0P/blob/main/Machine_learning_Middle_level_Neural_networks/03_Neural_networks_in_practice/keras_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании вам предстоит обучить модель классификации рукописных цифр на Tensorflow.
#
# Важным дополнительным требованием будет сохранение чекпоинтов на ваш гугл диск (не переживайтеЖ ниже будут подсказки, как это сделать). Это пригодится вам в дальнейшем при обучении более сложных моделей, на случай потери данных при неожиданном отключении Colab.

# %%
import tensorflow as tf
print(tf.__version__)
from google.colab import drive
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

 #tf.enable_eager_execution()
# Out:
# 2.8.0

# %% [markdown]
# ####Вспомогательный код

# %%
#@title 
def show_mnist(images, labels, predicted_labels=None):
    plt.figure(figsize=(10,10))
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.gray)
        if predicted_labels is not None:
            title_obj = plt.title(f"Real: {labels[i]}. Pred: {np.argmax(predicted_labels[i])}")
            if labels[i] != np.argmax(predicted_labels[i]):
                plt.setp(title_obj, color='r')
        else:
            plt.title(f"Real label: {labels[i]}")

def show_progress(history: dict):
    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(1,2,1)    
    plt.plot(history["accuracy"],label='train accuracy')
    plt.plot(history["val_accuracy"], label='test accuracy')
    ax2 = plt.subplot(1,2,2)
    plt.plot(history["loss"],label='train_loss')
    plt.plot(history["val_loss"],label='test_loss')
    
    ax1.legend(loc='best')
    ax2.legend(loc='best')
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Загрузка данных

# %%
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

show_mnist(x_train, y_train)
x_train = x_train.reshape((-1, 28*28)) # вытянули каждую картинку в вектор
x_test = x_test.reshape((-1, 28*28))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# прикрепим ваш гугл диск к виртуальной машине
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Путь до вашего гугл диска скорее всего выглядит так: /content/drive/My Drive/
# если эта клетка вызывает ошибку, 
# измените путь согласно ! ls "/content/drive/"

path = Path("/content/drive/My Drive/Skillbox/model_1")
path.mkdir(exist_ok=True, parents=True) # папка создается на вашем гугл диске. вместе с "родителями"
assert path.exists()
cpt_filename = "best_checkpoint_.hdf5"  
cpt_path =str(path / cpt_filename)
# После выполнения этой клетки, в вашем гугл диске должна создаться папка: Skillbox/model_1
# убедитесь в этом

# %% [markdown]
# А весь код ниже вы реализуете самостоятельно! Вы уже к этому готовы :)
# Требования к модели:
# 1. Точность на тестовой части выборки >96%
# 2. Чекпоинт модели с лучшими параметрами должен быть сохранен у вас на гугл диске
# 3. Объект history, который получается из model.fit(...) должен содержать значения лосса и accuracy для трейна и теста

# %%
# < YOUR CODE STARTS HERE >
checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor="val_accuracy", verbose=1, save_best_only=True, mode="max")
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=(784, )))
model.add(tf.keras.layers.Dense(30, activation="ReLU"))
model.add(tf.keras.layers.Dense(30, activation="ReLU"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

loss = tf.keras.losses.SparseCategoricalCrossentropy()

model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])

history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=200, batch_size=64, verbose=1, callbacks=[checkpoint])

# < YOUR CODE ENDS HERE >
# Out:
# Epoch 1/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.4165 - accuracy: 0.8806
# Epoch 1: val_accuracy improved from -inf to 0.92670, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.4163 - accuracy: 0.8806 - val_loss: 0.2463 - val_accuracy: 0.9267
# Epoch 2/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9426
# Epoch 2: val_accuracy improved from 0.92670 to 0.94970, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.1986 - accuracy: 0.9427 - val_loss: 0.1680 - val_accuracy: 0.9497
# Epoch 3/200
# 938/938 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9538
# Epoch 3: val_accuracy improved from 0.94970 to 0.95710, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.1568 - accuracy: 0.9538 - val_loss: 0.1448 - val_accuracy: 0.9571
# Epoch 4/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.1319 - accuracy: 0.9606
# Epoch 4: val_accuracy improved from 0.95710 to 0.96180, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.1319 - accuracy: 0.9606 - val_loss: 0.1364 - val_accuracy: 0.9618
# Epoch 5/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9648
# Epoch 5: val_accuracy did not improve from 0.96180
# 938/938 [==============================] - 3s 4ms/step - loss: 0.1167 - accuracy: 0.9648 - val_loss: 0.1355 - val_accuracy: 0.9614
# Epoch 6/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.1024 - accuracy: 0.9691
# Epoch 6: val_accuracy improved from 0.96180 to 0.96490, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 4ms/step - loss: 0.1024 - accuracy: 0.9690 - val_loss: 0.1244 - val_accuracy: 0.9649
# Epoch 7/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9718
# Epoch 7: val_accuracy did not improve from 0.96490
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0939 - accuracy: 0.9718 - val_loss: 0.1246 - val_accuracy: 0.9620
# Epoch 8/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0848 - accuracy: 0.9740
# Epoch 8: val_accuracy did not improve from 0.96490
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0847 - accuracy: 0.9740 - val_loss: 0.1216 - val_accuracy: 0.9644
# Epoch 9/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0779 - accuracy: 0.9762
# Epoch 9: val_accuracy did not improve from 0.96490
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0783 - accuracy: 0.9761 - val_loss: 0.1203 - val_accuracy: 0.9637
# Epoch 10/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9767
# Epoch 10: val_accuracy improved from 0.96490 to 0.96630, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0734 - accuracy: 0.9768 - val_loss: 0.1220 - val_accuracy: 0.9663
# Epoch 11/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0676 - accuracy: 0.9792
# Epoch 11: val_accuracy improved from 0.96630 to 0.96850, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0676 - accuracy: 0.9792 - val_loss: 0.1122 - val_accuracy: 0.9685
# Epoch 12/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0629 - accuracy: 0.9804
# Epoch 12: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0632 - accuracy: 0.9803 - val_loss: 0.1195 - val_accuracy: 0.9677
# Epoch 13/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0591 - accuracy: 0.9817
# Epoch 13: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0589 - accuracy: 0.9818 - val_loss: 0.1127 - val_accuracy: 0.9666
# Epoch 14/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9832
# Epoch 14: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0545 - accuracy: 0.9832 - val_loss: 0.1138 - val_accuracy: 0.9672
# Epoch 15/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0524 - accuracy: 0.9835
# Epoch 15: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0522 - accuracy: 0.9835 - val_loss: 0.1128 - val_accuracy: 0.9674
# Epoch 16/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0499 - accuracy: 0.9838
# Epoch 16: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0499 - accuracy: 0.9838 - val_loss: 0.1240 - val_accuracy: 0.9669
# Epoch 17/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0456 - accuracy: 0.9855
# Epoch 17: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0455 - accuracy: 0.9855 - val_loss: 0.1221 - val_accuracy: 0.9675
# Epoch 18/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0433 - accuracy: 0.9861
# Epoch 18: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0433 - accuracy: 0.9861 - val_loss: 0.1267 - val_accuracy: 0.9663
# Epoch 19/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9861
# Epoch 19: val_accuracy did not improve from 0.96850
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0419 - accuracy: 0.9861 - val_loss: 0.1234 - val_accuracy: 0.9661
# Epoch 20/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0385 - accuracy: 0.9880
# Epoch 20: val_accuracy improved from 0.96850 to 0.96900, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0385 - accuracy: 0.9880 - val_loss: 0.1235 - val_accuracy: 0.9690
# Epoch 21/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0379 - accuracy: 0.9878
# Epoch 21: val_accuracy did not improve from 0.96900
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0378 - accuracy: 0.9878 - val_loss: 0.1216 - val_accuracy: 0.9669
# Epoch 22/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9884
# Epoch 22: val_accuracy did not improve from 0.96900
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0353 - accuracy: 0.9883 - val_loss: 0.1278 - val_accuracy: 0.9676
# Epoch 23/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0322 - accuracy: 0.9893
# Epoch 23: val_accuracy did not improve from 0.96900
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0322 - accuracy: 0.9893 - val_loss: 0.1364 - val_accuracy: 0.9659
# Epoch 24/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0323 - accuracy: 0.9893
# Epoch 24: val_accuracy improved from 0.96900 to 0.96940, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint_.hdf5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0323 - accuracy: 0.9893 - val_loss: 0.1303 - val_accuracy: 0.9694
# Epoch 25/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0311 - accuracy: 0.9898
# Epoch 25: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0311 - accuracy: 0.9898 - val_loss: 0.1525 - val_accuracy: 0.9627
# Epoch 26/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9914
# Epoch 26: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0274 - accuracy: 0.9913 - val_loss: 0.1393 - val_accuracy: 0.9654
# Epoch 27/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9908
# Epoch 27: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0285 - accuracy: 0.9909 - val_loss: 0.1413 - val_accuracy: 0.9666
# Epoch 28/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0252 - accuracy: 0.9916
# Epoch 28: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0252 - accuracy: 0.9916 - val_loss: 0.1387 - val_accuracy: 0.9670
# Epoch 29/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0238 - accuracy: 0.9925
# Epoch 29: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0238 - accuracy: 0.9925 - val_loss: 0.1482 - val_accuracy: 0.9658
# Epoch 30/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 0.9920
# Epoch 30: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0247 - accuracy: 0.9920 - val_loss: 0.1531 - val_accuracy: 0.9664
# Epoch 31/200
# 920/938 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 0.9932
# Epoch 31: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0218 - accuracy: 0.9932 - val_loss: 0.1473 - val_accuracy: 0.9680
# Epoch 32/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0209 - accuracy: 0.9933
# Epoch 32: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.1609 - val_accuracy: 0.9646
# Epoch 33/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 0.9926
# Epoch 33: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.1560 - val_accuracy: 0.9652
# Epoch 34/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0195 - accuracy: 0.9937
# Epoch 34: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0195 - accuracy: 0.9937 - val_loss: 0.1762 - val_accuracy: 0.9625
# Epoch 35/200
# 926/938 [============================>.] - ETA: 0s - loss: 0.0194 - accuracy: 0.9937
# Epoch 35: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.1529 - val_accuracy: 0.9675
# Epoch 36/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0177 - accuracy: 0.9942
# Epoch 36: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0178 - accuracy: 0.9941 - val_loss: 0.1610 - val_accuracy: 0.9663
# Epoch 37/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0174 - accuracy: 0.9942
# Epoch 37: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0175 - accuracy: 0.9942 - val_loss: 0.1641 - val_accuracy: 0.9679
# Epoch 38/200
# 922/938 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9945
# Epoch 38: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.1665 - val_accuracy: 0.9677
# Epoch 39/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0169 - accuracy: 0.9947
# Epoch 39: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0170 - accuracy: 0.9946 - val_loss: 0.1757 - val_accuracy: 0.9668
# Epoch 40/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0156 - accuracy: 0.9948
# Epoch 40: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.1749 - val_accuracy: 0.9658
# Epoch 41/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0148 - accuracy: 0.9952
# Epoch 41: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.1699 - val_accuracy: 0.9677
# Epoch 42/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0168 - accuracy: 0.9941
# Epoch 42: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0168 - accuracy: 0.9941 - val_loss: 0.1811 - val_accuracy: 0.9670
# Epoch 43/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0127 - accuracy: 0.9961
# Epoch 43: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0128 - accuracy: 0.9960 - val_loss: 0.1845 - val_accuracy: 0.9671
# Epoch 44/200
# 926/938 [============================>.] - ETA: 0s - loss: 0.0146 - accuracy: 0.9951
# Epoch 44: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0146 - accuracy: 0.9951 - val_loss: 0.1984 - val_accuracy: 0.9633
# Epoch 45/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9955
# Epoch 45: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0137 - accuracy: 0.9955 - val_loss: 0.1899 - val_accuracy: 0.9660
# Epoch 46/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9948
# Epoch 46: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0150 - accuracy: 0.9948 - val_loss: 0.1929 - val_accuracy: 0.9647
# Epoch 47/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9952
# Epoch 47: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.2018 - val_accuracy: 0.9666
# Epoch 48/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9963
# Epoch 48: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.1902 - val_accuracy: 0.9670
# Epoch 49/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9954
# Epoch 49: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.1984 - val_accuracy: 0.9669
# Epoch 50/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9948
# Epoch 50: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0150 - accuracy: 0.9947 - val_loss: 0.2074 - val_accuracy: 0.9647
# Epoch 51/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0094 - accuracy: 0.9971
# Epoch 51: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.1974 - val_accuracy: 0.9663
# Epoch 52/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0102 - accuracy: 0.9968
# Epoch 52: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.2137 - val_accuracy: 0.9668
# Epoch 53/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0142 - accuracy: 0.9952
# Epoch 53: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 0.2211 - val_accuracy: 0.9664
# Epoch 54/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9966
# Epoch 54: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.2063 - val_accuracy: 0.9669
# Epoch 55/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0098 - accuracy: 0.9966
# Epoch 55: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.2166 - val_accuracy: 0.9662
# Epoch 56/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9957
# Epoch 56: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0118 - accuracy: 0.9957 - val_loss: 0.2320 - val_accuracy: 0.9644
# Epoch 57/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9971
# Epoch 57: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.2225 - val_accuracy: 0.9664
# Epoch 58/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9966
# Epoch 58: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.2247 - val_accuracy: 0.9654
# Epoch 59/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9978
# Epoch 59: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.2272 - val_accuracy: 0.9655
# Epoch 60/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9963
# Epoch 60: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.2250 - val_accuracy: 0.9655
# Epoch 61/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9969
# Epoch 61: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0093 - accuracy: 0.9969 - val_loss: 0.2326 - val_accuracy: 0.9662
# Epoch 62/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0092 - accuracy: 0.9968
# Epoch 62: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.2341 - val_accuracy: 0.9664
# Epoch 63/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9969
# Epoch 63: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.2366 - val_accuracy: 0.9639
# Epoch 64/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0103 - accuracy: 0.9964
# Epoch 64: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.2315 - val_accuracy: 0.9663
# Epoch 65/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0095 - accuracy: 0.9965
# Epoch 65: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0095 - accuracy: 0.9965 - val_loss: 0.2351 - val_accuracy: 0.9636
# Epoch 66/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9976
# Epoch 66: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0080 - accuracy: 0.9977 - val_loss: 0.2739 - val_accuracy: 0.9617
# Epoch 67/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9970
# Epoch 67: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 0.2387 - val_accuracy: 0.9659
# Epoch 68/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9971
# Epoch 68: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.2695 - val_accuracy: 0.9648
# Epoch 69/200
# 926/938 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9972
# Epoch 69: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.2494 - val_accuracy: 0.9645
# Epoch 70/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0090 - accuracy: 0.9970
# Epoch 70: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.2543 - val_accuracy: 0.9642
# Epoch 71/200
# 920/938 [============================>.] - ETA: 0s - loss: 0.0109 - accuracy: 0.9961
# Epoch 71: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.2612 - val_accuracy: 0.9662
# Epoch 72/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9990
# Epoch 72: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.2501 - val_accuracy: 0.9671
# Epoch 73/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9970
# Epoch 73: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.2541 - val_accuracy: 0.9655
# Epoch 74/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9975
# Epoch 74: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.2547 - val_accuracy: 0.9668
# Epoch 75/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9978
# Epoch 75: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.2599 - val_accuracy: 0.9678
# Epoch 76/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0113 - accuracy: 0.9961
# Epoch 76: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.2754 - val_accuracy: 0.9634
# Epoch 77/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9984
# Epoch 77: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.2644 - val_accuracy: 0.9663
# Epoch 78/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9982
# Epoch 78: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.2711 - val_accuracy: 0.9651
# Epoch 79/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0106 - accuracy: 0.9964
# Epoch 79: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.2916 - val_accuracy: 0.9656
# Epoch 80/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980
# Epoch 80: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.2595 - val_accuracy: 0.9656
# Epoch 81/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0101 - accuracy: 0.9968
# Epoch 81: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.2931 - val_accuracy: 0.9650
# Epoch 82/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 82: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.2727 - val_accuracy: 0.9657
# Epoch 83/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0097 - accuracy: 0.9968
# Epoch 83: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.2676 - val_accuracy: 0.9658
# Epoch 84/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0071 - accuracy: 0.9974
# Epoch 84: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.2865 - val_accuracy: 0.9640
# Epoch 85/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9982
# Epoch 85: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.2881 - val_accuracy: 0.9648
# Epoch 86/200
# 922/938 [============================>.] - ETA: 0s - loss: 0.0089 - accuracy: 0.9974
# Epoch 86: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.2878 - val_accuracy: 0.9643
# Epoch 87/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0076 - accuracy: 0.9976
# Epoch 87: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.2778 - val_accuracy: 0.9660
# Epoch 88/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9974
# Epoch 88: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.2866 - val_accuracy: 0.9662
# Epoch 89/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9979
# Epoch 89: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.2748 - val_accuracy: 0.9673
# Epoch 90/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9982
# Epoch 90: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.2828 - val_accuracy: 0.9662
# Epoch 91/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9974
# Epoch 91: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.2881 - val_accuracy: 0.9672
# Epoch 92/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9984
# Epoch 92: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.2863 - val_accuracy: 0.9662
# Epoch 93/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9989
# Epoch 93: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.2855 - val_accuracy: 0.9680
# Epoch 94/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0104 - accuracy: 0.9967
# Epoch 94: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.2967 - val_accuracy: 0.9661
# Epoch 95/200
# 922/938 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9977
# Epoch 95: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.3068 - val_accuracy: 0.9639
# Epoch 96/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0062 - accuracy: 0.9980
# Epoch 96: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.2998 - val_accuracy: 0.9648
# Epoch 97/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9985
# Epoch 97: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.2962 - val_accuracy: 0.9650
# Epoch 98/200
# 922/938 [============================>.] - ETA: 0s - loss: 0.0116 - accuracy: 0.9961
# Epoch 98: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0117 - accuracy: 0.9961 - val_loss: 0.3166 - val_accuracy: 0.9635
# Epoch 99/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9978
# Epoch 99: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.2931 - val_accuracy: 0.9669
# Epoch 100/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 100: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.3065 - val_accuracy: 0.9658
# Epoch 101/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0067 - accuracy: 0.9977
# Epoch 101: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.2974 - val_accuracy: 0.9678
# Epoch 102/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9973
# Epoch 102: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.3006 - val_accuracy: 0.9663
# Epoch 103/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9979
# Epoch 103: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.2881 - val_accuracy: 0.9682
# Epoch 104/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9986
# Epoch 104: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.3116 - val_accuracy: 0.9646
# Epoch 105/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 105: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.3065 - val_accuracy: 0.9665
# Epoch 106/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0120 - accuracy: 0.9959
# Epoch 106: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.3154 - val_accuracy: 0.9650
# Epoch 107/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9980
# Epoch 107: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.3009 - val_accuracy: 0.9673
# Epoch 108/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9987
# Epoch 108: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.3004 - val_accuracy: 0.9664
# Epoch 109/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9980
# Epoch 109: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.3068 - val_accuracy: 0.9666
# Epoch 110/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9972
# Epoch 110: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0078 - accuracy: 0.9972 - val_loss: 0.3248 - val_accuracy: 0.9648
# Epoch 111/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9985
# Epoch 111: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.3131 - val_accuracy: 0.9647
# Epoch 112/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0058 - accuracy: 0.9980
# Epoch 112: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.3287 - val_accuracy: 0.9641
# Epoch 113/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0083 - accuracy: 0.9976
# Epoch 113: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.3227 - val_accuracy: 0.9649
# Epoch 114/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983
# Epoch 114: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.3085 - val_accuracy: 0.9674
# Epoch 115/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9976
# Epoch 115: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.3204 - val_accuracy: 0.9668
# Epoch 116/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9984
# Epoch 116: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.3178 - val_accuracy: 0.9669
# Epoch 117/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 117: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.3264 - val_accuracy: 0.9652
# Epoch 118/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9974
# Epoch 118: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.3441 - val_accuracy: 0.9628
# Epoch 119/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972
# Epoch 119: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.3439 - val_accuracy: 0.9657
# Epoch 120/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9986
# Epoch 120: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.3454 - val_accuracy: 0.9650
# Epoch 121/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# Epoch 121: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.3603 - val_accuracy: 0.9637
# Epoch 122/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0065 - accuracy: 0.9979
# Epoch 122: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.3662 - val_accuracy: 0.9647
# Epoch 123/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9984
# Epoch 123: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.3539 - val_accuracy: 0.9644
# Epoch 124/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9979
# Epoch 124: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.3451 - val_accuracy: 0.9653
# Epoch 125/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9976
# Epoch 125: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.3335 - val_accuracy: 0.9666
# Epoch 126/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9988
# Epoch 126: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 0.3484 - val_accuracy: 0.9628
# Epoch 127/200
# 923/938 [============================>.] - ETA: 0s - loss: 0.0086 - accuracy: 0.9970
# Epoch 127: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.3274 - val_accuracy: 0.9676
# Epoch 128/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 128: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.3401 - val_accuracy: 0.9684
# Epoch 129/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9979
# Epoch 129: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.3497 - val_accuracy: 0.9651
# Epoch 130/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9981
# Epoch 130: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.3451 - val_accuracy: 0.9645
# Epoch 131/200
# 921/938 [============================>.] - ETA: 0s - loss: 0.0040 - accuracy: 0.9985
# Epoch 131: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.3308 - val_accuracy: 0.9654
# Epoch 132/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9981
# Epoch 132: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.3500 - val_accuracy: 0.9655
# Epoch 133/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986
# Epoch 133: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.3764 - val_accuracy: 0.9633
# Epoch 134/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0063 - accuracy: 0.9978
# Epoch 134: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.3573 - val_accuracy: 0.9657
# Epoch 135/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9980
# Epoch 135: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.3604 - val_accuracy: 0.9644
# Epoch 136/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0055 - accuracy: 0.9981
# Epoch 136: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.3335 - val_accuracy: 0.9676
# Epoch 137/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9975
# Epoch 137: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.3544 - val_accuracy: 0.9677
# Epoch 138/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992
# Epoch 138: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.3372 - val_accuracy: 0.9665
# Epoch 139/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9976
# Epoch 139: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.3643 - val_accuracy: 0.9647
# Epoch 140/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0041 - accuracy: 0.9987
# Epoch 140: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.3685 - val_accuracy: 0.9660
# Epoch 141/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9978
# Epoch 141: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.3645 - val_accuracy: 0.9652
# Epoch 142/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0042 - accuracy: 0.9986
# Epoch 142: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.3561 - val_accuracy: 0.9671
# Epoch 143/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0079 - accuracy: 0.9976
# Epoch 143: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.3571 - val_accuracy: 0.9659
# Epoch 144/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0032 - accuracy: 0.9988
# Epoch 144: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.3509 - val_accuracy: 0.9670
# Epoch 145/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0085 - accuracy: 0.9975
# Epoch 145: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.3650 - val_accuracy: 0.9673
# Epoch 146/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0043 - accuracy: 0.9984
# Epoch 146: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.3599 - val_accuracy: 0.9675
# Epoch 147/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9982
# Epoch 147: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.3777 - val_accuracy: 0.9669
# Epoch 148/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9984
# Epoch 148: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.3687 - val_accuracy: 0.9670
# Epoch 149/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0038 - accuracy: 0.9989
# Epoch 149: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.3748 - val_accuracy: 0.9666
# Epoch 150/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9977
# Epoch 150: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0078 - accuracy: 0.9977 - val_loss: 0.3656 - val_accuracy: 0.9686
# Epoch 151/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9982
# Epoch 151: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.3908 - val_accuracy: 0.9669
# Epoch 152/200
# 925/938 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9983
# Epoch 152: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.3813 - val_accuracy: 0.9667
# Epoch 153/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0031 - accuracy: 0.9991
# Epoch 153: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.3707 - val_accuracy: 0.9669
# Epoch 154/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9986
# Epoch 154: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0052 - accuracy: 0.9985 - val_loss: 0.3951 - val_accuracy: 0.9650
# Epoch 155/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9974
# Epoch 155: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.3798 - val_accuracy: 0.9663
# Epoch 156/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0068 - accuracy: 0.9978
# Epoch 156: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.3833 - val_accuracy: 0.9664
# Epoch 157/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 157: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.3850 - val_accuracy: 0.9668
# Epoch 158/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 158: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.4109 - val_accuracy: 0.9639
# Epoch 159/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9981
# Epoch 159: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.3877 - val_accuracy: 0.9665
# Epoch 160/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0073 - accuracy: 0.9978
# Epoch 160: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.3731 - val_accuracy: 0.9665
# Epoch 161/200
# 933/938 [============================>.] - ETA: 0s - loss: 6.5531e-04 - accuracy: 0.9999
# Epoch 161: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 6.5240e-04 - accuracy: 0.9999 - val_loss: 0.3771 - val_accuracy: 0.9669
# Epoch 162/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0099 - accuracy: 0.9973
# Epoch 162: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.4050 - val_accuracy: 0.9655
# Epoch 163/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0047 - accuracy: 0.9986
# Epoch 163: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.4006 - val_accuracy: 0.9657
# Epoch 164/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0048 - accuracy: 0.9984
# Epoch 164: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.3887 - val_accuracy: 0.9659
# Epoch 165/200
# 933/938 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9990
# Epoch 165: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.4088 - val_accuracy: 0.9653
# Epoch 166/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976
# Epoch 166: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.4049 - val_accuracy: 0.9667
# Epoch 167/200
# 922/938 [============================>.] - ETA: 0s - loss: 0.0037 - accuracy: 0.9988
# Epoch 167: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.3936 - val_accuracy: 0.9668
# Epoch 168/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0050 - accuracy: 0.9984
# Epoch 168: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.4036 - val_accuracy: 0.9659
# Epoch 169/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 169: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.4183 - val_accuracy: 0.9652
# Epoch 170/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0030 - accuracy: 0.9991
# Epoch 170: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.3930 - val_accuracy: 0.9677
# Epoch 171/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0049 - accuracy: 0.9988
# Epoch 171: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.4189 - val_accuracy: 0.9668
# Epoch 172/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9978
# Epoch 172: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.4303 - val_accuracy: 0.9665
# Epoch 173/200
# 926/938 [============================>.] - ETA: 0s - loss: 0.0066 - accuracy: 0.9980
# Epoch 173: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.4228 - val_accuracy: 0.9652
# Epoch 174/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0034 - accuracy: 0.9990
# Epoch 174: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.4013 - val_accuracy: 0.9675
# Epoch 175/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9992
# Epoch 175: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.4098 - val_accuracy: 0.9675
# Epoch 176/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0087 - accuracy: 0.9974
# Epoch 176: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.4100 - val_accuracy: 0.9664
# Epoch 177/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0023 - accuracy: 0.9993
# Epoch 177: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.4107 - val_accuracy: 0.9653
# Epoch 178/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0088 - accuracy: 0.9978
# Epoch 178: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.4313 - val_accuracy: 0.9671
# Epoch 179/200
# 931/938 [============================>.] - ETA: 0s - loss: 0.0024 - accuracy: 0.9991
# Epoch 179: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.4268 - val_accuracy: 0.9675
# Epoch 180/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0039 - accuracy: 0.9986
# Epoch 180: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.4630 - val_accuracy: 0.9630
# Epoch 181/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0057 - accuracy: 0.9981
# Epoch 181: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.4452 - val_accuracy: 0.9656
# Epoch 182/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0035 - accuracy: 0.9989
# Epoch 182: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.4101 - val_accuracy: 0.9679
# Epoch 183/200
# 930/938 [============================>.] - ETA: 0s - loss: 6.6941e-04 - accuracy: 0.9998
# Epoch 183: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 7.1918e-04 - accuracy: 0.9998 - val_loss: 0.4486 - val_accuracy: 0.9667
# Epoch 184/200
# 938/938 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9969
# Epoch 184: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0119 - accuracy: 0.9969 - val_loss: 0.4496 - val_accuracy: 0.9666
# Epoch 185/200
# 937/938 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9992
# Epoch 185: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.4632 - val_accuracy: 0.9656
# Epoch 186/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0061 - accuracy: 0.9981
# Epoch 186: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.4538 - val_accuracy: 0.9645
# Epoch 187/200
# 930/938 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9984
# Epoch 187: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.4658 - val_accuracy: 0.9633
# Epoch 188/200
# 934/938 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9983
# Epoch 188: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.4369 - val_accuracy: 0.9667
# Epoch 189/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0053 - accuracy: 0.9984
# Epoch 189: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.4575 - val_accuracy: 0.9657
# Epoch 190/200
# 929/938 [============================>.] - ETA: 0s - loss: 0.0051 - accuracy: 0.9984
# Epoch 190: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.4355 - val_accuracy: 0.9653
# Epoch 191/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0029 - accuracy: 0.9992
# Epoch 191: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.4425 - val_accuracy: 0.9665
# Epoch 192/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0072 - accuracy: 0.9979
# Epoch 192: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.4412 - val_accuracy: 0.9660
# Epoch 193/200
# 926/938 [============================>.] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 193: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.4380 - val_accuracy: 0.9639
# Epoch 194/200
# 936/938 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9977
# Epoch 194: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.4537 - val_accuracy: 0.9645
# Epoch 195/200
# 928/938 [============================>.] - ETA: 0s - loss: 0.0012 - accuracy: 0.9998
# Epoch 195: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.4869 - val_accuracy: 0.9635
# Epoch 196/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0105 - accuracy: 0.9973
# Epoch 196: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.4391 - val_accuracy: 0.9675
# Epoch 197/200
# 927/938 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 197: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.4308 - val_accuracy: 0.9668
# Epoch 198/200
# 932/938 [============================>.] - ETA: 0s - loss: 0.0059 - accuracy: 0.9981
# Epoch 198: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.4422 - val_accuracy: 0.9663
# Epoch 199/200
# 935/938 [============================>.] - ETA: 0s - loss: 0.0046 - accuracy: 0.9984
# Epoch 199: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 3s 4ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.4367 - val_accuracy: 0.9656
# Epoch 200/200
# 924/938 [============================>.] - ETA: 0s - loss: 0.0020 - accuracy: 0.9994
# Epoch 200: val_accuracy did not improve from 0.96940
# 938/938 [==============================] - 4s 4ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.4284 - val_accuracy: 0.9675

# %%
assert len(list(path.glob("*"))) != 0, f"Checkpoint dir {path}"
assert "accuracy" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
assert "val_accuracy" in history.history, "Please, provide validation_data in model.fit."
assert np.max(history.history["val_accuracy"]) > 0.95, "Validation accuracy must be more than 0.95"
# Для старой версии (tf.__version__ == 1.x) запустить aseert-ы ниже:
# assert "acc" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
# assert "val_acc" in history.history, "Please, provide validation_data in model.fit."
# assert np.max(history.history["val_acc"]) > 0.95, "Validation accuracy must be more than 0.95"
print("Training tests passed")
# Out:
# Training tests passed

# %% [markdown]
# Давайте посмотрим на графики обучения:

# %%
show_progress(history.history)

# %% [markdown]
# А теперь перейдем к загрузке модели. Если все реализовано правильно, то код ниже должен сработать без ошибок:

# %%
restored_model = tf.keras.models.load_model(cpt_path)
loss, acc = restored_model.evaluate(x_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
assert acc > 0.96
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1303 - accuracy: 0.9694
# Accuracy of restored model 96.94%

# %% [markdown]
# И, наконец, можно сравнить предсказания с реальными классами (с такой точностью найти ошибку будет сложно):

# %%
predicted_labels = restored_model.predict(x_test)
idxs = np.random.choice(np.arange(len(x_test)), 16, replace=False)
show_mnist(x_test[idxs].reshape((-1, 28, 28)), y_test[idxs], predicted_labels[idxs])
