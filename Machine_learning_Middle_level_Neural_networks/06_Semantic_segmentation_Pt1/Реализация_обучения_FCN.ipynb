# %% [markdown]
# <a href="https://colab.research.google.com/github/larinsi/DS0P/blob/main/Machine_learning_Middle_level_Neural_networks/06_Semantic_segmentation_Pt1/%D0%A0%D0%B5%D0%B0%D0%BB%D0%B8%D0%B7%D0%B0%D1%86%D0%B8%D1%8F_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8F_FCN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Реализация обучения FCN
# В этом модуле мы создадим нашу первую FCN модель для задачи Семантической Сегментации. А также построим пайплайн обучения этой модели.
#
# Обучение такой модели на реальных данных займет достаточно длительное время. Поэтому мы будем обучаться на очень маленьком датасете, состоящем из одной картинки (и её зеркальной копии). При таком подходе мы столкнемся с проблемой переобучения ("запоминание" обучающей выборки и отсутствие обобщения), но ничего страшного. Нам лишь нужно будет протестировать, что пайплайн и модель работают корректно.

# %% [markdown]
# ### Загрузка необходимых библиотек
# Здесь мы загружаем различные библиотеки, включая TensoFlow.

# %%
import random
import imageio
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf
#tf.enable_eager_execution()
print('TensorFlow version:', tf.__version__)
# Out:
# 2022-04-25 19:51:51.653075: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# TensorFlow version: 2.4.1

# %% [markdown]
# # Подготовка датасета

# %% [markdown]
# ### Загрузка и подготовка входного изображения
# Файл 'me_256.png' должен находится в текущей директории. Вам необходимо загрузить его туда  самостоятельно, используя кнопку UPLOAD во вкладке Files в левой панели.

# %%
img = imageio.imread('6.11_me_256.png')
img = img.astype(np.float32) / 255
_=plt.imshow(img)

# %% [markdown]
# ### Загрузка и подготовка карты сегментации человек/фон
# То же самое касается файла 'me_gt_256.png'.
#
# После загрузки мы приводим 3 канала RGB к одному каналу путём усреднения.
#
# Это наша Ground-Truth карта сегментации, размеченная кем-то (мною) вручную.
# Значение `'0'` в ней означает класс "фон", значение `'1'` -- класс "человек"

# %%
gt = imageio.imread('6.11_me_gt_256.png')
gt = gt.astype(np.float32) / 255.
gt = np.mean(gt, axis=2)[..., None]
_=plt.imshow(gt[...,0])

# %% [markdown]
# ### Подготовка обучающего датасета
# Наша цель создать и протестировать пайплайн для обучения FCN модели, включая данные, модель, лосс и т.д.
#
# Поэтому для простоты эксперимента возьмем очень простой датасет, состоящий из двух изображений: загруженная картинка и её зеркально отраженная копия.
#
# Индексирование `'::-1'` означает взять все элементы в обратном порядке.
#
# При обучении на таком маленьком датасете модель переобучится, но в данном примере нас это не будет беспокоить. Наша цель - отладить пайплайн, поэтому тестировать будем на том же, на чём и обучались.

# %%
train_x = np.stack((img, img[:,::-1,:]))
train_y = np.stack((gt, gt[:,::-1,:]))

plt.imshow(train_x[0]), plt.show()
plt.imshow(train_y[0][...,0]), plt.show()
plt.imshow(train_x[1]), plt.show()
plt.imshow(train_y[1][...,0]), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f4b78971850>, None)

# %% [markdown]
# # Пайплайн обучения FCN

# %% [markdown]
# ### Создание FCN модели
# В TensorFlow есть несколько способов создать нейросетевую модель. Ранее мы создавали модель с помощью `tf.keras.Sequential`, где нужно было просто перечислить последовательность слоёв. Кроме того, вы знакомы с функциональным способом создания модели, в котором мы строим наш вычислительных граф, соединяя различные операции, что даёт нам возможность получить произвольный граф из слоёв, а не только линейный (последовательный), как в случае Sequential.
#
# Есть и третий способ создать модель -- создать свой собственный класс, наследованный от `tf.keras.Model`. Это самый гибкий способ, при таком подходе можно создавать абсолютно любые графы, в том числе динамические, то есть с произвольным потоком управления (control flow). В такой граф можно вставлять проверки условий, циклы и практически любые функции из Питона и TensorFlow.
#
# Организовать такой класс мы можем произвольным образом, но как минимум нам надо реализовать конструктор `__init__()` и функцию для прямого распространения (инференса) нашего графа `call()`. В конструкторе мы создаём нужные нам слои и другие необходимые вещи. А в методе `call()` используем эти слои для вычисления прямого распространения (инференса) нашей сети. То есть именно в функции `call()` задается архитектура нашей нейронной сети путём написания кода в стиле обычного Питона.
#
# Так как наш граф является динамическим и в TensorFlow мы включили режим жадного (eager) выполнения, написанный в функции `call()` код (то есть вычисления всех слоёв) будет выполняться прямо в момент вызова `call()` (не раньше и не позже), так же как и в обычном Питоне.
#
# В результате вычисления слоёв (прохода по динамическому графу) нас интересуют две вещи. Первая вещь - финальный выход нейронной сети (то, что возвращает функция `call()`). Если нас не интересуют промежуточные данные (что было на выходе первого, второго слоя и.т.д) и эти тензоры больше нигде не используются, мы можем записывать выход каждого слоя в переменную с тем же именем (например, `out`) и передавать её на вход в следующий слой. Вторая вещь - запоминание пути, по которому шло прямое распространение, чтобы TensorFlow смог сделать backpropagation по "обратному" пути. Эта вторая вещь делается в TensorFlow автоматически, если мы используем так называемую градиентную ленту (Gradient Tape) или же используем функцию `fit()` из Keras для обучения модели (этот способ мы использовали ранее).
#
# Созданный нами класс по сути то же является "слоем", так что мы можем использовать его как "слой" в каких-то других нейросетях. Таким образом можно создавать сложный нейронные сети модульно, сначала простые модели, а потом более сложные модули на их основе. Это нам пригодится в будущем. А пока что создадим довольно простую FCN с участием Свёрточных слоёв, Pooling слоёв и Upscale.
#
# В качестве Upscale будем использовать билинейную интерполяцию. Для этого важно использовать функцию из TensorFlow (`tf.image.resize`), а не аналоги из Питона, чтобы для этой функции можно было посчитать backpropagation. В TensorFlow есть аналоги практически все математических и других питон функций, которые могут потребоваться при создании произвольных нейросетей.
#
# **[ЗАДАНИЕ 1]** Вопрос: В конструкторе нашей модели мы создали отдельный экземпляр для каждого свёрточного слоя. А почему мы создали лишь один экземпляр Pooling слоя, несмотря на то, что в сети у нас есть несколько Pooling слоёв?

# %%
class Model(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv2 = tf.keras.layers.Conv2D(64, (3, 3), padding='same', activation='relu')
        self.conv3 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv4 = tf.keras.layers.Conv2D(128, (3, 3), padding='same', activation='relu')
        self.conv5 = tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu')
        self.conv6 = tf.keras.layers.Conv2D(1, (3, 3), padding='same', activation=None)
        self.pool = tf.keras.layers.MaxPool2D((2, 2))
        
    def call(self, x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.pool(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.pool(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out = tf.image.resize(out, (x.shape[1], x.shape[2]), tf.image.ResizeMethod.BILINEAR)
        out = tf.nn.sigmoid(out)
        return out
    
model = Model()
# Out:
# 2022-04-25 19:51:53.747110: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-04-25 19:51:53.748380: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-04-25 19:51:53.761693: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.762106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: NVIDIA GeForce GTX 1060 6GB computeCapability: 6.1
# coreClock: 1.7845GHz coreCount: 10 deviceMemorySize: 5.93GiB deviceMemoryBandwidth: 178.99GiB/s
# 2022-04-25 19:51:53.762129: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-25 19:51:53.763325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-25 19:51:53.763367: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-25 19:51:53.764538: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-25 19:51:53.764721: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-25 19:51:53.765982: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-25 19:51:53.766766: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-25 19:51:53.769567: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-25 19:51:53.769725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.770185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.770758: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-04-25 19:51:53.771109: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-25 19:51:53.771762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.772162: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: NVIDIA GeForce GTX 1060 6GB computeCapability: 6.1
# coreClock: 1.7845GHz coreCount: 10 deviceMemorySize: 5.93GiB deviceMemoryBandwidth: 178.99GiB/s
# 2022-04-25 19:51:53.772197: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-25 19:51:53.772218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-04-25 19:51:53.772229: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-04-25 19:51:53.772240: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-04-25 19:51:53.772251: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-04-25 19:51:53.772261: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-04-25 19:51:53.772273: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-04-25 19:51:53.772284: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-25 19:51:53.772353: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.772868: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:53.773213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-04-25 19:51:53.773244: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-04-25 19:51:54.156720: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-04-25 19:51:54.156753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-04-25 19:51:54.156762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-04-25 19:51:54.156985: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:54.157417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:54.157823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-25 19:51:54.158235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5139 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:07:00.0, compute capability: 6.1)
# 2022-04-25 19:51:54.158595: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %% [markdown]
# ### Обучение FCN модели
# В конце предыдущего блока мы создали объект `model` как экземпляр нашего класса `Model`.
# Обучить такую модель теперь можно точно так же, как и любую другу модель в TensorFlow.
#
# Так как на выходе в каждом пикселе у нас лишь одно значение (бинарная классификация "фон"/"человек"), то в сети в самом конце у нас использовалась функция `sigmoid`, выход которой в диапазоне от 0 до 1. Ground-Truth наш так же имеет одно значение в каждом пикселе (0 или 1).
#
# Для обучения такой модели с таким Ground-Truth'ом нам понадобится вот такая лосс функция: `tf.keras.losses.BinaryCrossentropy()` (бинарная кросс-энтропия): https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy
#
# На выходе такой функции скаляр, так что если на входе был многомерный тензор, то автоматически происходит суммирование (reduce) по всем измерениям. Именно это нам и нужно для построения лосса для семантической сегментации.
#
# **[ЗАДАНИЕ 2]** Реализуйте пайплайн обучения описанной выше модели `model`, как это делалось для других задач обучения в tensorFlow. Используйте созданные выше `train_x` и `train_y` в качестве обучающего датасета. Так как в обучающей выборке у нас всего два объекта, чтобы сеть обучалась подольше, возьмите побольше эпох, например 100. Постройте график зависимости лосса от эпохи.

# %%
# %%time
# Ваш код здесь


model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')
hist = model.fit(train_x,train_y, epochs=100, batch_size=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <bound method Model.call of <__main__.Model object at 0x7f4b788f5790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Model.call of <__main__.Model object at 0x7f4b788f5790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2022-04-25 19:51:54.279396: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-04-25 19:51:54.279804: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3193515000 Hz
# 2022-04-25 19:51:54.831488: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-04-25 19:51:55.312894: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2022-04-25 19:51:55.351108: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2022-04-25 19:51:55.768693: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2/2 [==============================] - 8s 19ms/step - loss: 0.6886 - accuracy: 0.4036
# Epoch 2/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.6503 - accuracy: 0.8159
# Epoch 3/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.5435 - accuracy: 0.8159
# Epoch 4/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.3483 - accuracy: 0.8858
# Epoch 5/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2382 - accuracy: 0.8806
# Epoch 6/100
# 2/2 [==============================] - 0s 18ms/step - loss: 0.2158 - accuracy: 0.8769
# Epoch 7/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2146 - accuracy: 0.8804
# Epoch 8/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2063 - accuracy: 0.8769
# Epoch 9/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2035 - accuracy: 0.8780
# Epoch 10/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2038 - accuracy: 0.8807
# Epoch 11/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2010 - accuracy: 0.8763
# Epoch 12/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1953 - accuracy: 0.8822
# Epoch 13/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1899 - accuracy: 0.8813
# Epoch 14/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1818 - accuracy: 0.8843
# Epoch 15/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1716 - accuracy: 0.8960
# Epoch 16/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1510 - accuracy: 0.9074
# Epoch 17/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2106 - accuracy: 0.9325
# Epoch 18/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.7077 - accuracy: 0.6748
# Epoch 19/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7803 - accuracy: 0.7096
# Epoch 20/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2610 - accuracy: 0.8747
# Epoch 21/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.2205 - accuracy: 0.9049
# Epoch 22/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.3181 - accuracy: 0.9199
# Epoch 23/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2788 - accuracy: 0.9324
# Epoch 24/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2215 - accuracy: 0.9113
# Epoch 25/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.2004 - accuracy: 0.8969
# Epoch 26/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.2067 - accuracy: 0.8814
# Epoch 27/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2132 - accuracy: 0.8765
# Epoch 28/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.2030 - accuracy: 0.8768
# Epoch 29/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1906 - accuracy: 0.8795
# Epoch 30/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1813 - accuracy: 0.8878
# Epoch 31/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1784 - accuracy: 0.9015
# Epoch 32/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1743 - accuracy: 0.9040
# Epoch 33/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1651 - accuracy: 0.9051
# Epoch 34/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1545 - accuracy: 0.9223
# Epoch 35/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1405 - accuracy: 0.9291
# Epoch 36/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1246 - accuracy: 0.9470
# Epoch 37/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1058 - accuracy: 0.9688
# Epoch 38/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.1216 - accuracy: 0.9446
# Epoch 39/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.1014 - accuracy: 0.9491
# Epoch 40/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0801 - accuracy: 0.9707
# Epoch 41/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0739 - accuracy: 0.9750
# Epoch 42/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0659 - accuracy: 0.9775
# Epoch 43/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0603 - accuracy: 0.9801
# Epoch 44/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0566 - accuracy: 0.9787
# Epoch 45/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0509 - accuracy: 0.9819
# Epoch 46/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0463 - accuracy: 0.9827
# Epoch 47/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0435 - accuracy: 0.9842
# Epoch 48/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0394 - accuracy: 0.9850
# Epoch 49/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0384 - accuracy: 0.9858
# Epoch 50/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0334 - accuracy: 0.9871
# Epoch 51/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0307 - accuracy: 0.9879
# Epoch 52/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0284 - accuracy: 0.9888
# Epoch 53/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0265 - accuracy: 0.9894
# Epoch 54/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0253 - accuracy: 0.9899
# Epoch 55/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0242 - accuracy: 0.9903
# Epoch 56/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0232 - accuracy: 0.9908
# Epoch 57/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0223 - accuracy: 0.9912
# Epoch 58/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0212 - accuracy: 0.9917
# Epoch 59/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0203 - accuracy: 0.9920
# Epoch 60/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0198 - accuracy: 0.9924
# Epoch 61/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0194 - accuracy: 0.9927
# Epoch 62/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0184 - accuracy: 0.9930
# Epoch 63/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0178 - accuracy: 0.9931
# Epoch 64/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0170 - accuracy: 0.9934
# Epoch 65/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0164 - accuracy: 0.9938
# Epoch 66/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0158 - accuracy: 0.9940
# Epoch 67/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0153 - accuracy: 0.9942
# Epoch 68/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0179 - accuracy: 0.9931
# Epoch 69/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0180 - accuracy: 0.9930
# Epoch 70/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0173 - accuracy: 0.9934
# Epoch 71/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0172 - accuracy: 0.9934
# Epoch 72/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0149 - accuracy: 0.9945
# Epoch 73/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0147 - accuracy: 0.9943
# Epoch 74/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0155 - accuracy: 0.9941
# Epoch 75/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0149 - accuracy: 0.9943
# Epoch 76/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 77/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0139 - accuracy: 0.9946
# Epoch 78/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0133 - accuracy: 0.9950
# Epoch 79/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0126 - accuracy: 0.9952
# Epoch 80/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0123 - accuracy: 0.9953
# Epoch 81/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0121 - accuracy: 0.9955
# Epoch 82/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0120 - accuracy: 0.9955
# Epoch 83/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0117 - accuracy: 0.9956
# Epoch 84/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0115 - accuracy: 0.9958
# Epoch 85/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0111 - accuracy: 0.9958
# Epoch 86/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0108 - accuracy: 0.9961
# Epoch 87/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0109 - accuracy: 0.9958
# Epoch 88/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0105 - accuracy: 0.9962
# Epoch 89/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0101 - accuracy: 0.9963
# Epoch 90/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0099 - accuracy: 0.9963
# Epoch 91/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0102 - accuracy: 0.9962
# Epoch 92/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0097 - accuracy: 0.9964
# Epoch 93/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0093 - accuracy: 0.9965
# Epoch 94/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0092 - accuracy: 0.9966
# Epoch 95/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0090 - accuracy: 0.9966
# Epoch 96/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0091 - accuracy: 0.9965
# Epoch 97/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0099 - accuracy: 0.9961
# Epoch 98/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0092 - accuracy: 0.9967
# Epoch 99/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0102 - accuracy: 0.9958
# Epoch 100/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0090 - accuracy: 0.9966
# CPU times: user 5.26 s, sys: 3.1 s, total: 8.37 s
# Wall time: 11.5 s

# %% [markdown]
# ### Результат предсказания на входной картинке
# Протестируем результат работы модели `model` на входной картинке `img`.
#
# Не забудем приклеить дополнительное батч измерение с помощью `[None, ...]`, а потом отрезать его с помощью `[0, ...]`

# %%
out = model.predict(img[None, ...])[0, ...]
_=plt.imshow(out[...,0])

# %% [markdown]
# ### Результат предсказания для всех картинок
# По непрерывному предсказанию FCN модели (от нуля до единицы) получим дискретную карту сегментации помощью порога (0.5).
#
# Далее наложим полученную карту сегментации (после преобразования в цветную картинку с колормапом jet) на исходную картинку. Сделаем это для обоих объектов в обучающей выборке.

# %%
for sample in train_x:
    out = model.predict(sample[None, ...])
    seg_map = (out[0, ..., 0]>0.5).astype(np.float32)
    seg_map_clr = plt.get_cmap('viridis')(seg_map)[..., :3]
    plt.imshow(sample*0.5 + seg_map_clr*0.5)
    plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['accuracy'])
